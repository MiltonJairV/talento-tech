# %% [markdown]
# <a href="https://colab.research.google.com/github/MiltonJairV/talento-tech/blob/main/1entrenamiento/ejercicio_tabla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
lista_nombres = ["Alexander", "Alejandra", "Dario", "Wilson"]
lista_pesos=[69,57,64,80]
lista_alturas=[1.78,1.60,1.64,1.71]
# convierte el dicc en un datafrem (marco de datos=tabla=dataset=conjunto de datos)
dicc_datos={"Nombre":lista_nombres,"Peso":lista_pesos,"Altura":lista_alturas}
df = pd.DataFrame(dicc_datos)
df
# Out:
#       Nombre  Peso  Altura
# 0  Alexander    69    1.78
# 1  Alejandra    57    1.60
# 2      Dario    64    1.64
# 3     Wilson    80    1.71

# %%
import pandas as pd
lista_nombres = ["Ana","Hernán","Ramón","Sandra","Camilo","Mariana","Manuel","Daniela","Henry","Lina","David","Paula","Luis","Andréa","Antonio"]
lista_pesos=[60,45,90,56,62,35,65,56,72,63,92,36,15,62,10]
lista_alturas=[1.62,1.72,1.75,1.58,1.69,1.02,1.69,1.52,1.65,1.66,1.83,138,1.15,1.60,1.05 ]
# convierte el dicc en un datafrem (marco de datos= tabla=dataset=conjunto de datos)
dicc_datos={"nombre":lista_nombres, "pesos":lista_pesos,"altura":lista_alturas}
df = pd.DataFrame(dicc_datos)
df
# Out:
#      nombre  pesos  altura
# 0       Ana     60    1.62
# 1    Hernán     45    1.72
# 2     Ramón     90    1.75
# 3    Sandra     56    1.58
# 4    Camilo     62    1.69
# 5   Mariana     35    1.02
# 6    Manuel     65    1.69
# 7   Daniela     56    1.52
# 8     Henry     72    1.65
# 9      Lina     63    1.66
# 10    David     92    1.83
# 11    Paula     36  138.00
# 12     Luis     15    1.15
# 13   Andréa     62    1.60
# 14  Antonio     10    1.05

# %%
df
# Out:
#      nombre  pesos  altura
# 0       Ana     60    1.62
# 1    Hernán     45    1.72
# 2     Ramón     90    1.75
# 3    Sandra     56    1.58
# 4    Camilo     62    1.69
# 5   Mariana     35    1.02
# 6    Manuel     65    1.69
# 7   Daniela     56    1.52
# 8     Henry     72    1.65
# 9      Lina     63    1.66
# 10    David     92    1.83
# 11    Paula     36  138.00
# 12     Luis     15    1.15
# 13   Andréa     62    1.60
# 14  Antonio     10    1.05

# %%
df
# Out:
#      nombre  pesos  altura
# 0       Ana     60    1.62
# 1    Hernán     45    1.72
# 2     Ramón     90    1.75
# 3    Sandra     56    1.58
# 4    Camilo     62    1.69
# 5   Mariana     35    1.02
# 6    Manuel     65    1.69
# 7   Daniela     56    1.52
# 8     Henry     72    1.65
# 9      Lina     63    1.66
# 10    David     92    1.83
# 11    Paula     36  138.00
# 12     Luis     15    1.15
# 13   Andréa     62    1.60
# 14  Antonio     10    1.05
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['pesos'].plot(kind='hist', bins=20, title='pesos')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['altura'].plot(kind='hist', bins=20, title='altura')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
# ...

# %%
df
# Out:
#      nombre  pesos  altura
# 0       Ana     60    1.62
# 1    Hernán     45    1.72
# 2     Ramón     90    1.75
# 3    Sandra     56    1.58
# 4    Camilo     62    1.69
# 5   Mariana     35    1.02
# 6    Manuel     65    1.69
# 7   Daniela     56    1.52
# 8     Henry     72    1.65
# 9      Lina     63    1.66
# 10    David     92    1.83
# 11    Paula     36  138.00
# 12     Luis     15    1.15
# 13   Andréa     62    1.60
# 14  Antonio     10    1.05

# %%
df["bmi"]=df["pesos"]/df["altura"]**2
df
# Out:
#      nombre  pesos  altura        bmi
# 0       Ana     60    1.62  22.862369
# 1    Hernán     45    1.72  15.210925
# 2     Ramón     90    1.75  29.387755
# 3    Sandra     56    1.58  22.432303
# 4    Camilo     62    1.69  21.707923
# 5   Mariana     35    1.02  33.640907
# 6    Manuel     65    1.69  22.758307
# 7   Daniela     56    1.52  24.238227
# 8     Henry     72    1.65  26.446281
# 9      Lina     63    1.66  22.862534
# 10    David     92    1.83  27.471707
# 11    Paula     36  138.00   0.001890
# 12     Luis     15    1.15  11.342155
# 13   Andréa     62    1.60  24.218750
# 14  Antonio     10    1.05   9.070295

# %%
df.describe()
# Out:
#            pesos      altura        bmi
# count  15.000000   15.000000  15.000000
# mean   54.600000   10.635333  20.910155
# std    23.384366   35.235293   8.639713
# min    10.000000    1.020000   0.001890
# 25%    40.500000    1.550000  18.459424
# 50%    60.000000    1.650000  22.862369
# 75%    64.000000    1.705000  25.342254
# max    92.000000  138.000000  33.640907

# %%
#Estadistica descriptiva para las columnas categóricas (nombre)

descripcion_persona = df['nombre'].describe()
print(descripcion_persona)
# Out:
# count      15
# unique     15
# top       Ana
# freq        1
# Name: nombre, dtype: object

# %%
#Cargar dataset en google colab
import pandas as pd

# Subo el archivo llamado 'Uso_del_asistente_IA.csv'
df = pd.read_csv('Uso_del_asistente_IA.csv')

print(df.head())
# Out:
#       SessionID   StudentLevel        Discipline SessionDate  \
# 0  SESSION00001  Undergraduate  Computer Science  2024-11-03
# 1  SESSION00002  Undergraduate        Psychology  2024-08-25
# 2  SESSION00003  Undergraduate          Business  2025-01-12
# 3  SESSION00004  Undergraduate  Computer Science  2025-05-06
# 4  SESSION00005  Undergraduate        Psychology  2025-03-18
#
#    SessionLengthMin  TotalPrompts  TaskType  AI_AssistanceLevel  \
# 0             31.20            11  Studying                   2
# 1             13.09             6  Studying                   3
# 2             19.22             5    Coding                   3
# 3              3.70             1    Coding                   3
# 4             28.12             9   Writing                   3
#
#            FinalOutcome  UsedAgain  SatisfactionRating
# 0  Assignment Completed       True                 1.0
# 1  Assignment Completed       True                 2.0
# ...
